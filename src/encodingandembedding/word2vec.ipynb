# %%
import pandas as pd
import numpy as np
import gensim
import os
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# ...

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
for file in os.listdir('../../public/data/word2vec'):
    print(file)
# Out:
# story1.txt
# story2.txt

# %%
f = open(r'D:\Vishal Projs\My_Projects\SeptPy\LearningGenerativeAi\public\data\word2vec\story1.txt')

# %%
corpus = f.read()

# %%
corpus
# Out:
# 'Once upon a time, there was a young boy named Arjun who lived in a small town surrounded by hills and rivers. He was very curious about how things worked and always asked questions. His parents often smiled at his curiosity and encouraged him to learn more.\n\nEvery day after school, Arjun would sit with his books and explore different topics. He was especially fascinated by science and technology. He wanted to understand how machines think and whether they could become as intelligent as humans.\n\nOne day, while browsing through an old computer at school, Arjun discovered the concept of artificial intelligence. He read about how machines can learn from data, recognize patterns, and even make decisions. This idea completely amazed him.\n\nHe started imagining a future where machines could help humans solve complex problems. That day, he made a decision that he wanted to become an AI engineer.\n\nArjun began learning programming using free resources. At first, everything seemed diffi
# ...

# %%
sent_tokenize(corpus)
# Out:
# ['Once upon a time, there was a young boy named Arjun who lived in a small town surrounded by hills and rivers.',
#  'He was very curious about how things worked and always asked questions.',
#  'His parents often smiled at his curiosity and encouraged him to learn more.',
#  'Every day after school, Arjun would sit with his books and explore different topics.',
#  'He was especially fascinated by science and technology.',
#  'He wanted to understand how machines think and whether they could become as intelligent as humans.',
#  'One day, while browsing through an old computer at school, Arjun discovered the concept of artificial intelligence.',
#  'He read about how machines can learn from data, recognize patterns, and even make decisions.',
#  'This idea completely amazed him.',
#  'He started imagining a future where machines could help humans solve complex problems.',
#  'That day, he made a decision that he wanted to become an AI engineer.',
# ...

# %%
raw_sent = sent_tokenize(corpus)

# %%
for i in raw_sent:
    print(simple_preprocess(i))
# Out:
# ['once', 'upon', 'time', 'there', 'was', 'young', 'boy', 'named', 'arjun', 'who', 'lived', 'in', 'small', 'town', 'surrounded', 'by', 'hills', 'and', 'rivers']
# ['he', 'was', 'very', 'curious', 'about', 'how', 'things', 'worked', 'and', 'always', 'asked', 'questions']
# ['his', 'parents', 'often', 'smiled', 'at', 'his', 'curiosity', 'and', 'encouraged', 'him', 'to', 'learn', 'more']
# ['every', 'day', 'after', 'school', 'arjun', 'would', 'sit', 'with', 'his', 'books', 'and', 'explore', 'different', 'topics']
# ['he', 'was', 'especially', 'fascinated', 'by', 'science', 'and', 'technology']
# ['he', 'wanted', 'to', 'understand', 'how', 'machines', 'think', 'and', 'whether', 'they', 'could', 'become', 'as', 'intelligent', 'as', 'humans']
# ['one', 'day', 'while', 'browsing', 'through', 'an', 'old', 'computer', 'at', 'school', 'arjun', 'discovered', 'the', 'concept', 'of', 'artificial', 'intelligence']
# ...

# %%
folder_path = r"D:\Vishal Projs\My_Projects\SeptPy\LearningGenerativeAi\public\data\word2vec"
story = []
for filename in os.listdir(folder_path):
  file_path=os.path.join(folder_path,filename)
  with open(file_path,encoding='unicode_escape') as f:
    corpus=f.read()
  raw_sent=sent_tokenize(corpus)
  for sent in raw_sent:
    story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 44

# %%
story[0]
# Out:
# ['once',
#  'upon',
#  'time',
#  'there',
#  'was',
#  'young',
#  'boy',
#  'named',
#  'arjun',
#  'who',
#  'lived',
#  'in',
#  'small',
#  'town',
#  'surrounded',
#  'by',
#  'hills',
#  'and',
#  'rivers']

# %%
custom_model = gensim.models.Word2Vec(
    window=12,
    min_count=1,
    vector_size=250
)

# %%
custom_model.build_vocab(story)

# %%
len(custom_model.wv.index_to_key)
# Out:
# 257

# %%
custom_model.corpus_count
# Out:
# 44

# %%
custom_model.train(story,total_examples=custom_model.corpus_count,epochs=11)
# Out:
# (3688, 5742)

# %%
custom_model.wv["arjun"]
# Out:
# array([ 1.33858179e-03,  3.28900031e-04, -6.81638077e-04,  4.33896482e-03,
#         6.35458680e-04,  1.47309690e-03, -1.65504549e-04,  1.27598934e-03,
#         2.39365431e-03, -1.67281847e-04,  9.72383365e-04, -9.15327691e-05,
#         1.73759100e-03,  1.08390546e-03,  1.17148482e-03, -2.26439396e-03,
#        -2.58081802e-03,  1.80483609e-03, -2.77899695e-03, -3.00307292e-04,
#        -5.57470543e-04,  1.60634157e-03, -2.85379216e-03,  3.57618043e-03,
#        -4.17398347e-04, -2.07314570e-03,  1.82949891e-03, -9.58615274e-04,
#        -3.61857726e-03, -1.53289700e-03, -2.55184772e-04, -3.36465216e-03,
#        -1.17572956e-04,  7.64056633e-04, -4.12968016e-04,  8.30526871e-04,
#         1.24356558e-03,  3.54818953e-03,  6.82447746e-04,  5.18884975e-04,
#         5.58962813e-04, -2.31442755e-04, -4.14654147e-03,  3.51028563e-03,
#        -5.46701835e-04, -4.10436839e-03, -2.65862397e-03, -1.83507125e-03,
# ...

# %%
len(custom_model.wv["arjun"])
# Out:
# 250

# %%
custom_model.wv.most_similar("programming")
# Out:
# [('interest', 0.18037545680999756),
#  ('create', 0.17768779397010803),
#  ('hard', 0.171137273311615),
#  ('time', 0.16617578268051147),
#  ('who', 0.1590145230293274),
#  ('recognize', 0.14610803127288818),
#  ('proved', 0.13411705195903778),
#  ('frustrated', 0.13379620015621185),
#  ('even', 0.13351936638355255),
#  ('realized', 0.1272895634174347)]

# %%
custom_model.wv.most_similar("engineer")
# Out:
# [('working', 0.14090920984745026),
#  ('shared', 0.13619132339954376),
#  ('whether', 0.12820501625537872),
#  ('just', 0.12246491760015488),
#  ('everything', 0.12051977962255478),
#  ('solve', 0.12025842815637589),
#  ('about', 0.11847342550754547),
#  ('each', 0.11597021669149399),
#  ('decided', 0.11521922051906586),
#  ('old', 0.11159632354974747)]

# %%
custom_model.wv.doesnt_match(["science","ai","farmer","programming"])
# Out:
# 'science'

# %%
custom_model.wv.similarity("ai", "technology")
# Out:
# 0.10382555

# %%
custom_model.wv.similarity("arjun", "engineer")
# Out:
# -0.05877423

# %%
custom_model.wv.similarity("ai","farmers")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 custom_model.wv.similarity("ai","farming")
#
# File d:\Vishal Projs\My_Projects\SeptPy\LearningGenerativeAi\.venv\Lib\site-packages\gensim\models\keyedvectors.py:1234, in KeyedVectors.similarity(self, w1, w2)
#    1218 def similarity(self, w1, w2):
#    1219     """Compute cosine similarity between two keys.
#    1220
#    1221     Parameters
#    (...)   1232
#    1233     """
# -> 1234     return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#
# File d:\Vishal Projs\My_Projects\SeptPy\LearningGenerativeAi\.venv\Lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)    400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# ...
