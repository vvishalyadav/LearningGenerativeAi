# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documents = [
    "people watch movie and watch movie again",
    "people watch cricker and watch cricket",
    "people like movie and like movie a lot",
    "people like cricket"
]

# %%
tfidf = TfidfVectorizer()

# %%
tfidf_matrix  = tfidf.fit_transform(documents)

# %%
tfidf_matrix.toarray()
# Out:
# array([[0.38771136, 0.24747114, 0.        , 0.        , 0.        ,
#         0.        , 0.61135218, 0.20232387, 0.61135218],
#        [0.        , 0.29171108, 0.45702177, 0.36032121, 0.        ,
#         0.        , 0.        , 0.23849292, 0.72064242],
#        [0.        , 0.24747114, 0.        , 0.        , 0.61135218,
#         0.38771136, 0.61135218, 0.20232387, 0.        ],
#        [0.        , 0.        , 0.        , 0.64043405, 0.64043405,
#         0.        , 0.        , 0.42389674, 0.        ]])

# %%
tfidf.get_feature_names_out()
# Out:
# array(['again', 'and', 'cricker', 'cricket', 'like', 'lot', 'movie',
#        'people', 'watch'], dtype=object)
